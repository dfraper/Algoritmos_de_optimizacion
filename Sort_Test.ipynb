# %% [markdown]
# <a href="https://colab.research.google.com/github/dfraper/Algoritmos_de_optimizacion/blob/main/Sort_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sorting
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sorting: filename=sorting-1.0.3-py3-none-any.whl size=5859 sha256=7f95b5784630110599aa84109e186a556cc2c0113e7fc2ddb435990f75bcba56
#   Stored in directory: /root/.cache/pip/wheels/1e/4f/b2/859fb60c464ab3d3d9526a5ec0f3d3166f5b9a1c719dee88ad
# Successfully built sorting
# ...

# %%
import sorting

lista = [4, 5, 32, 2, 53, 67, 23]

lista_ordenada = sorting.bubble (lista)
print (lista_ordenada)
# Out:
# [2, 4, 5, 23, 32, 53, 67]
